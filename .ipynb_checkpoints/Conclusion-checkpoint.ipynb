# %% [markdown]
# ![parks and art.png](attachment:3a3352e2-f865-4c9c-9f6b-105c4e7ecb56.png)

# %% [markdown]
# From our analysis, we found that Squirrel Hill South is the best neighborhood in Pittsburgh. We added all the occurences of Public Art and Playgrounds than ilustrated the top 30 in a bar chart for each neighborhood. The neighborhood with the most occurences of Public Art and Playgrounds is Squirrel Hill South.
